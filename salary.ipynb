# %%
import pandas as pd 
sdf=pd.read_csv('salaries.csv')
sdf
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8460\1804276386.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#        company                  job     degree  salary_more_then_100k
# 0       google      sales executive  bachelors                      0
# 1       google      sales executive    masters                      0
# 2       google     business manager  bachelors                      1
# 3       google     business manager    masters                      1
# 4       google  computer programmer  bachelors                      0
# ...

# %%
sdf1=pd.get_dummies(sdf,dtype=int)
x=sdf1.drop(columns='salary_more_then_100k')
y=sdf['salary_more_then_100k']
x
# Out:
#     company_abc pharma  company_facebook  company_google  \
# 0                    0                 0               1
# 1                    0                 0               1
# 2                    0                 0               1
# 3                    0                 0               1
# 4                    0                 0               1
# 5                    0                 0               1
# 6                    1                 0               0
# 7                    1                 0               0
# 8                    1                 0               0
# 9                    1                 0               0
# 10                   0                 1               0
# 11                   0                 1               0
# 12                   0                 1               0
# 13                   0                 1               0
# 14                   0                 1               0
# ...

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.15)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 1, 1], dtype=int64)

# %%
model.score(x,y)
# Out:
# 0.9375

# %%
num=int(input())
company=input('Enter company:')
job=input('Enter your role:')
degree=input('Enter your degree:')
list=[]
for i in range(num):
    n=[]
    if(company=='abc pharma'):
        n.append(1)
        n.append(0)
        n.append(0)
    elif(company=='facebook'):
        n.append(0)
        n.append(1)
        n.append(0)
    elif(company=='google'):
        n.append(0)
        n.append(0)
        n.append(1)
    if(job=='business manager'):
        n.append(1)
        n.append(0)
        n.append(0)
    elif(job=='computer programmer'):
        n.append(0)
        n.append(1)
        n.append(0)
    elif(job=='sales executive'):
        n.append(0)
        n.append(0)
        n.append(1)
    if(degree=='bachelors'):
        n.append(1)
        n.append(0)
    elif(degree=='master'):
        n.append(0)
        n.append(1)
    list.append(n)
    print
model=LogisticRegression()
model.fit(x,y)
ans=model.predict(list)
print(ans)
# Out:
#  1
# Enter company: google
# Enter your role: business manager
# Enter your degree: bachelor
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 41
#      39 model=LogisticRegression()
#      40 model.fit(x,y)
# ---> 41 ans=model.predict(list)
#      42 print(ans)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
# ...
